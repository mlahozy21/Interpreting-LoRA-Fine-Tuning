# %% [markdown]
# # What Does LoRA Change? — interpretability study
#
# Fine-tune Qwen2.5-1.5B with LoRA and analyse **where** it puts its capacity and
# **how much** it moves the model's representations, across ranks and module sets.
#
# **Runtime → GPU** before running.

# %%
# !nvidia-smi

# %%
# !git clone https://github.com/mlahozy21/Interpreting-LoRA-Fine-Tuning.git
# %cd Interpreting-LoRA-Fine-Tuning
# !pip install -q -e .
# !pip uninstall -y torchao  # avoid Colab's peft/torchao clash (unused)

# %% [markdown]
# ### Quick single-config demo (a few minutes)

# %%
# !python scripts/quick_demo.py

# %% [markdown]
# ### Full ablation study (rank x module set) — longer

# %%
# !python scripts/run_study.py --ranks 4 16 64 --targets attn all --max-samples 2000 --epochs 1

# %% [markdown]
# Figures land in `figures/` and a summary in `results.csv`.
